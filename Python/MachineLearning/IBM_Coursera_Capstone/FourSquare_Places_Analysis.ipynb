# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# %%
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML

# %%
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
#CLIENT_ID = '' # your Foursquare ID
#CLIENT_SECRET = '' # your Foursquare Secret


VERSION = '20191129'
LIMIT = 30

# %%
address = '520 S Michigan Ave, Chicago, IL 60605, USA'
geolocator = Nominatim(user_agent="foursquare_agent", timeout=10)
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)


#https://api.foursquare.com/v2/venues/search?client_id=CLIENT_ID&client_secret=CLIENT_SECRET&ll=LATITUDE,LONGITUDE&v=VERSION&query=QUERY&radius=RADIUS&limit=LIMIT

search_query = 'Restaurant'
radius = 500
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
print(url)

results = requests.get(url).json()
results
# Out:
# 41.87490815 -87.6248194228993
# Restaurant .... OK!
# https://api.foursquare.com/v2/venues/search?client_id=VBB0KYSN0QAINUIOWHG4RHGZ4TJ3PW0L5XAB3EGKCRKHYKHT&client_secret=BAKGJ433ZOWHUBM4WDFRIHHTSMSY3MDMZFPDDWL1ZPNU3WUV&ll=41.87490815,-87.6248194228993&v=20191129&query=Restaurant&radius=500&limit=30
# {'meta': {'code': 200, 'requestId': '5ddfeeecb1cac0001bef4bff'},
#  'response': {'venues': [{'id': '4b2bedd4f964a520e6bd24e3',
#     'name': 'The Berghoff Restaurant',
#     'location': {'address': '17 W Adams St',
#      'crossStreet': 'btwn S Dearborn St & S State St',
#      'lat': 41.879334126547164,
#      'lng': -87.62836809709047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.879334126547164,
#        'lng': -87.62836809709047}],
#      'distance': 573,
#      'postalCode': '60603',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['17 W Adams St (btwn S Dearborn St & S State St)',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10d941735',
#       'name': 'German Restaurant',
#       'pluralName': 'German Restaurants',
#       'shortName': 'German',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '90487382'},
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '40b28c80f964a52037fb1ee3',
#     'name': 'Exchequer Restaurant & Pub',
#     'location': {'address': '226 S Wabash Ave',
#      'lat': 41.87881928744278,
#      'lng': -87.62598621466157,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87881928744278,
#        'lng': -87.62598621466157}],
#      'distance': 445,
#      'postalCode': '60604',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['226 S Wabash Ave',
#       'Chicago, IL 60604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '541230',
#      'url': 'https://www.grubhub.com/restaurant/exchequer-restaurant--pub-226-s-wabash-ave-chicago/541230?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=541230',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4b9ad8c5f964a520ccdb35e3',
#     'name': 'Plymouth Restaurant & Bar',
#     'location': {'address': '327 S Plymouth Ct',
#      'crossStreet': 'btwn W Jackson Blvd & W Van Buren St',
#      'lat': 41.87713751627466,
#      'lng': -87.62796900098705,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87713751627466,
#        'lng': -87.62796900098705}],
#      'distance': 360,
#      'postalCode': '60604',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['327 S Plymouth Ct (btwn W Jackson Blvd & W Van Buren St)',
#       'Chicago, IL 60604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '51d896fc498ea6557a53478f',
#     'name': 'Sofi Restaurant',
#     'location': {'address': '616 S Dearborn St',
#      'lat': 41.873879614620975,
#      'lng': -87.62910524547061,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.873879614620975,
#        'lng': -87.62910524547061}],
#      'distance': 373,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['616 S Dearborn St',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4a4d85a8f964a520f9ad1fe3',
#     'name': 'Chicago Curry House Indian Restaurant',
#     'location': {'address': '899 S Plymouth Ct',
#      'crossStreet': 'at W 9th St',
#      'lat': 41.870602848827794,
#      'lng': -87.62820876713214,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.870602848827794,
#        'lng': -87.62820876713214}],
#      'distance': 555,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['899 S Plymouth Ct (at W 9th St)',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '68528',
#      'url': 'https://www.grubhub.com/restaurant/chicago-curry-house---indian--nepalese-cuisine-899-s-plymouth-ct-chicago/68528?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=68528',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '5d8136d5adf8620008fd8200',
#     'name': 'Opus Restaurant & Café',
#     'location': {'address': '65 E Adams St',
#      'crossStreet': 'Wabash',
#      'lat': 41.879321000000004,
#      'lng': -87.625508,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.879321000000004,
#        'lng': -87.625508}],
#      'distance': 494,
#      'postalCode': '60603',
#      'cc': 'US',
#      'neighborhood': 'The Loop',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['65 E Adams St (Wabash)',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '58a3360a3493553f56f942a7',
#     'name': 'Luna Cafe Restaurant',
#     'location': {'address': '63 E Harrison St',
#      'crossStreet': 'Wabash',
#      'lat': 41.874670691907355,
#      'lng': -87.62552529638134,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.874670691907355,
#        'lng': -87.62552529638134}],
#      'distance': 64,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['63 E Harrison St (Wabash)',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '59866e4616ef6757600d2419',
#     'name': 'Himalayan Restaurant',
#     'location': {'address': '606 S Wabash Ave',
#      'lat': 41.8741292184772,
#      'lng': -87.62606358943373,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.8741292184772,
#        'lng': -87.62606358943373}],
#      'distance': 134,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['606 S Wabash Ave',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '471262',
#      'url': 'https://www.grubhub.com/restaurant/himalayan-restaurant-606-s-wabash-ave-chicago/471262?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=471262',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4e99a54a30f8e35f55cc3852',
#     'name': 'Gazebo Restaurant at Grant Park',
#     'location': {'address': '520 S Michigan Ave',
#      'crossStreet': 'Congress Parkway',
#      'lat': 41.875607,
#      'lng': -87.624503,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.875607,
#        'lng': -87.624503}],
#      'distance': 82,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['520 S Michigan Ave (Congress Parkway)',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '53b667f8498e13dbda6f1b45',
#     'name': 'Lord Gore Restaurant',
#     'location': {'address': '595 Vail Valley Drive',
#      'lat': 41.87571237049921,
#      'lng': -87.62500047683716,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87571237049921,
#        'lng': -87.62500047683716}],
#      'distance': 90,
#      'postalCode': '60611',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['595 Vail Valley Drive',
#       'Chicago, IL 60611',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4b3aca57f964a5207b6e25e3',
#     'name': 'Amarit Thai Restaurant',
#     'location': {'address': '600 S Dearborn St',
#      'lat': 41.87430180555001,
#      'lng': -87.62912378722385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87430180555001,
#        'lng': -87.62912378722385}],
#      'distance': 363,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['600 S Dearborn St',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '190',
#      'url': 'https://www.grubhub.com/restaurant/amarit-thai--sushi-600-s-dearborn-st-chicago/190?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=190',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '80499402'},
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '5c114c8d2a7ab6002c9c6105',
#     'name': 'Rawabi Grill Mediterranean Restaurant',
#     'location': {'address': '24 E Adams St',
#      'lat': 41.879632,
#      'lng': -87.626753,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.879632,
#        'lng': -87.626753}],
#      'distance': 549,
#      'postalCode': '60603',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['24 E Adams St',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '5220fe1b498ebc08f2dc3f56',
#     'name': 'McKinlock Court Restaurant',
#     'location': {'lat': 41.87958409645068,
#      'lng': -87.62184606033443,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87958409645068,
#        'lng': -87.62184606033443}],
#      'distance': 575,
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['Chicago, IL', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4c22547b9085d13a742886cc',
#     'name': 'G & G Restaurant',
#     'location': {'address': '24 E Adams St',
#      'crossStreet': 'at Wabash',
#      'lat': 41.87937231091048,
#      'lng': -87.62673858744276,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87937231091048,
#        'lng': -87.62673858744276}],
#      'distance': 521,
#      'postalCode': '60603',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['24 E Adams St (at Wabash)',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4cf44dcf6195721eef9251c1',
#     'name': "HALO' Restaurant - Chicago",
#     'location': {'address': '29 E Adams St',
#      'lat': 41.879262,
#      'lng': -87.626611,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.879262,
#        'lng': -87.626611}],
#      'distance': 506,
#      'postalCode': '60603',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['29 E Adams St',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '49d8159cf964a520a05d1fe3',
#     'name': "Miller's Pub",
#     'location': {'address': '134 S Wabash Ave',
#      'crossStreet': 'btwn E Adams & E Monroe St',
#      'lat': 41.87980606438684,
#      'lng': -87.62596591869482,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87980606438684,
#        'lng': -87.62596591869482}],
#      'distance': 553,
#      'postalCode': '60603',
#      'cc': 'US',
#      'neighborhood': 'The Loop',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['134 S Wabash Ave (btwn E Adams & E Monroe St)',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4bfa87015efe2d7f77b46d34',
#     'name': 'Dearborn Dentistry',
#     'location': {'address': '539 S Dearborn St',
#      'crossStreet': 'at W Harrison St',
#      'lat': 41.874879,
#      'lng': -87.628939,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.874879,
#        'lng': -87.628939}],
#      'distance': 341,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['539 S Dearborn St (at W Harrison St)',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d178941735',
#       'name': "Dentist's Office",
#       'pluralName': "Dentist's Offices",
#       'shortName': "Dentist's Office",
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4bd9c2e3e914a59305c957fa',
#     'name': 'La Cocina Mexican Grill',
#     'location': {'address': '406 S Clark St',
#      'crossStreet': 'Van Buren',
#      'lat': 41.87664114402268,
#      'lng': -87.63069212152591,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87664114402268,
#        'lng': -87.63069212152591}],
#      'distance': 523,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['406 S Clark St (Van Buren)',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '432158',
#      'url': 'https://www.grubhub.com/restaurant/la-cocina-restaurant-406-s-clark-st-chicago/432158?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=432158',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4bad0cc6f964a52052283be3',
#     'name': 'Plymouth Street',
#     'location': {'address': '327 S Plymouth Ct',
#      'lat': 41.877361,
#      'lng': -87.628751,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.877361,
#        'lng': -87.628751}],
#      'distance': 425,
#      'postalCode': '60604',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['327 S Plymouth Ct',
#       'Chicago, IL 60604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f9931735',
#       'name': 'Road',
#       'pluralName': 'Roads',
#       'shortName': 'Road',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4d63f9ffd37c88bf879535c1',
#     'name': 'Subway',
#     'location': {'address': '77 W Jackson Blvd',
#      'crossStreet': 'at S Clark St',
#      'lat': 41.87778146968472,
#      'lng': -87.6306040365589,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.87778146968472,
#        'lng': -87.6306040365589}],
#      'distance': 576,
#      'postalCode': '60604',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['77 W Jackson Blvd (at S Clark St)',
#       'Chicago, IL 60604',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4b47fdf5f964a520f24526e3',
#     'name': "Gino's East",
#     'location': {'address': '521 S Dearborn St',
#      'crossStreet': 'at Congress Pkwy',
#      'lat': 41.875304850081875,
#      'lng': -87.62921970466826,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.875304850081875,
#        'lng': -87.62921970466826}],
#      'distance': 367,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['521 S Dearborn St (at Congress Pkwy)',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '269256',
#      'url': 'https://www.grubhub.com/restaurant/ginos-east-southloop-521-s-dearborn-st-chicago/269256?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=269256',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '4bb541582f70c9b6b0008430',
#     'name': 'S.R.O. - Standing Room Only',
#     'location': {'address': '610 S Dearborn St',
#      'crossStreet': 'at W Harrison St',
#      'lat': 41.874025012001574,
#      'lng': -87.62898086313432,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.874025012001574,
#        'lng': -87.62898086313432}],
#      'distance': 358,
#      'postalCode': '60605',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['610 S Dearborn St (at W Harrison St)',
#       'Chicago, IL 60605',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '446',
#      'url': 'https://www.grubhub.com/restaurant/standing-room-only-610-s-dearborn-st-chicago/446?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=446',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'venuePage': {'id': '92507275'},
#     'referralId': 'v-1574956790',
#     'hasPerk': False},
#    {'id': '52efeef5498e5dceb7c8360f',
#     'name': 'Middle Eastern Restaurants',
#     'location': {'address': '24 E Adams St',
#      'lat': 41.8795495480299,
#      'lng': -87.62692898511887,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.8795495480299,
#        'lng': -87.62692898511887}],
#      'distance': 545,
#      'postalCode': '60603',
#      'cc': 'US',
#      'city': 'Chicago',
#      'state': 'IL',
#      'country': 'United States',
#      'formattedAddress': ['24 E Adams St',
#       'Chicago, IL 60603',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1574956790',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                   name  \
# 0  4b2bedd4f964a520e6bd24e3  The Berghoff Restaurant
# 1  40b28c80f964a52037fb1ee3  Exchequer Restaurant & Pub
# 2  4b9ad8c5f964a520ccdb35e3  Plymouth Restaurant & Bar
# 3  51d896fc498ea6557a53478f  Sofi Restaurant
# 4  4a4d85a8f964a520f9ad1fe3  Chicago Curry House Indian Restaurant
#
#                                                                                                                                                                                                                                        categories  \
# 0  [{'id': '4bf58dd8d48988d10d941735', 'name': 'German Restaurant', 'pluralName': 'German Restaurants', 'shortName': 'German', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_', 'suffix': '.png'}, 'primary': True}]
# 1  [{'id': '4bf58dd8d48988d11b941735', 'name': 'Pub', 'pluralName': 'Pubs', 'shortName': 'Pub', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}, 'primary': True}]
# 2  [{'id': '4bf58dd8d48988d116941735', 'name': 'Bar', 'pluralName': 'Bars', 'shortName': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}, 'primary': True}]
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'Indian Restaurant', 'pluralName': 'Indian Restaurants', 'shortName': 'Indian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}, 'primary': True}]
#
#      referralId  hasPerk   location.address  \
# 0  v-1574956790  False    17 W Adams St
# 1  v-1574956790  False    226 S Wabash Ave
# 2  v-1574956790  False    327 S Plymouth Ct
# 3  v-1574956790  False    616 S Dearborn St
# 4  v-1574956790  False    899 S Plymouth Ct
#
#                    location.crossStreet  location.lat  location.lng  \
# 0  btwn S Dearborn St & S State St       41.879334    -87.628368
# 1  NaN                                   41.878819    -87.625986
# 2  btwn W Jackson Blvd & W Van Buren St  41.877138    -87.627969
# 3  NaN                                   41.873880    -87.629105
# 4  at W 9th St                           41.870603    -87.628209
#
#                                                         location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 41.879334126547164, 'lng': -87.62836809709047}]
# 1  [{'label': 'display', 'lat': 41.87881928744278, 'lng': -87.62598621466157}]
# 2  [{'label': 'display', 'lat': 41.87713751627466, 'lng': -87.62796900098705}]
# 3  [{'label': 'display', 'lat': 41.873879614620975, 'lng': -87.62910524547061}]
# 4  [{'label': 'display', 'lat': 41.870602848827794, 'lng': -87.62820876713214}]
#
#    ...  location.country  \
# 0  ...  United States
# 1  ...  United States
# 2  ...  United States
# 3  ...  United States
# 4  ...  United States
#
#                                                                       location.formattedAddress  \
# 0  [17 W Adams St (btwn S Dearborn St & S State St), Chicago, IL 60603, United States]
# 1  [226 S Wabash Ave, Chicago, IL 60604, United States]
# 2  [327 S Plymouth Ct (btwn W Jackson Blvd & W Van Buren St), Chicago, IL 60604, United States]
# 3  [616 S Dearborn St, Chicago, IL 60605, United States]
# 4  [899 S Plymouth Ct (at W 9th St), Chicago, IL 60605, United States]
#
#   venuePage.id delivery.id  \
# 0  90487382     NaN
# 1  NaN          541230
# 2  NaN          NaN
# 3  NaN          NaN
# 4  NaN          68528
#
#                                                                                                                                                                                                                         delivery.url  \
# 0  NaN
# 1  https://www.grubhub.com/restaurant/exchequer-restaurant--pub-226-s-wabash-ave-chicago/541230?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=541230
# 2  NaN
# 3  NaN
# 4  https://www.grubhub.com/restaurant/chicago-curry-house---indian--nepalese-cuisine-899-s-plymouth-ct-chicago/68528?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=68528
#
#   delivery.provider.name             delivery.provider.icon.prefix  \
# 0  NaN                    NaN
# 1  grubhub                https://fastly.4sqi.net/img/general/cap/
# 2  NaN                    NaN
# 3  NaN                    NaN
# 4  grubhub                https://fastly.4sqi.net/img/general/cap/
#
#   delivery.provider.icon.sizes              delivery.provider.icon.name  \
# 0  NaN                          NaN
# 1  [40, 50]                     /delivery_provider_grubhub_20180129.png
# 2  NaN                          NaN
# 3  NaN                          NaN
# 4  [40, 50]                     /delivery_provider_grubhub_20180129.png
#
#   location.neighborhood
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 25 columns]

# %%
filtered_columns = [ 'name', 'categories' ] + [ col for col in dataframe.columns if col.startswith('location.') ] + [ 'id' ]
#filtered_columns
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered
# Out:
#                                      name                 categories  \
# 0   The Berghoff Restaurant                German Restaurant
# 1   Exchequer Restaurant & Pub             Pub
# 2   Plymouth Restaurant & Bar              Bar
# 3   Sofi Restaurant                        Italian Restaurant
# 4   Chicago Curry House Indian Restaurant  Indian Restaurant
# 5   Opus Restaurant & Café                 Café
# 6   Luna Cafe Restaurant                   Restaurant
# 7   Himalayan Restaurant                   Indian Restaurant
# 8   Gazebo Restaurant at Grant Park        American Restaurant
# 9   Lord Gore Restaurant                   Restaurant
# 10  Amarit Thai Restaurant                 Thai Restaurant
# 11  Rawabi Grill Mediterranean Restaurant  Mediterranean Restaurant
# 12  McKinlock Court Restaurant             Snack Place
# 13  G & G Restaurant                       Restaurant
# 14  HALO' Restaurant - Chicago             Asian Restaurant
# 15  Miller's Pub                           Pub
# 16  Dearborn Dentistry                     Dentist's Office
# 17  La Cocina Mexican Grill                Mexican Restaurant
# 18  Plymouth Street                        Road
# 19  Subway                                 Sandwich Place
# 20  Gino's East                            Pizza Place
# 21  S.R.O. - Standing Room Only            American Restaurant
# 22  Middle Eastern Restaurants             Middle Eastern Restaurant
#
#          location.address                  location.crossStreet  location.lat  \
# 0   17 W Adams St          btwn S Dearborn St & S State St       41.879334
# 1   226 S Wabash Ave       NaN                                   41.878819
# 2   327 S Plymouth Ct      btwn W Jackson Blvd & W Van Buren St  41.877138
# 3   616 S Dearborn St      NaN                                   41.873880
# 4   899 S Plymouth Ct      at W 9th St                           41.870603
# 5   65 E Adams St          Wabash                                41.879321
# 6   63 E Harrison St       Wabash                                41.874671
# 7   606 S Wabash Ave       NaN                                   41.874129
# 8   520 S Michigan Ave     Congress Parkway                      41.875607
# 9   595 Vail Valley Drive  NaN                                   41.875712
# 10  600 S Dearborn St      NaN                                   41.874302
# 11  24 E Adams St          NaN                                   41.879632
# 12  NaN                    NaN                                   41.879584
# 13  24 E Adams St          at Wabash                             41.879372
# 14  29 E Adams St          NaN                                   41.879262
# 15  134 S Wabash Ave       btwn E Adams & E Monroe St            41.879806
# 16  539 S Dearborn St      at W Harrison St                      41.874879
# 17  406 S Clark St         Van Buren                             41.876641
# 18  327 S Plymouth Ct      NaN                                   41.877361
# 19  77 W Jackson Blvd      at S Clark St                         41.877781
# 20  521 S Dearborn St      at Congress Pkwy                      41.875305
# 21  610 S Dearborn St      at W Harrison St                      41.874025
# 22  24 E Adams St          NaN                                   41.879550
#
#     location.lng  \
# 0  -87.628368
# 1  -87.625986
# 2  -87.627969
# 3  -87.629105
# 4  -87.628209
# 5  -87.625508
# 6  -87.625525
# 7  -87.626064
# 8  -87.624503
# 9  -87.625000
# 10 -87.629124
# 11 -87.626753
# 12 -87.621846
# 13 -87.626739
# 14 -87.626611
# 15 -87.625966
# 16 -87.628939
# 17 -87.630692
# 18 -87.628751
# 19 -87.630604
# 20 -87.629220
# 21 -87.628981
# 22 -87.626929
#
#                                                          location.labeledLatLngs  \
# 0   [{'label': 'display', 'lat': 41.879334126547164, 'lng': -87.62836809709047}]
# 1   [{'label': 'display', 'lat': 41.87881928744278, 'lng': -87.62598621466157}]
# 2   [{'label': 'display', 'lat': 41.87713751627466, 'lng': -87.62796900098705}]
# 3   [{'label': 'display', 'lat': 41.873879614620975, 'lng': -87.62910524547061}]
# 4   [{'label': 'display', 'lat': 41.870602848827794, 'lng': -87.62820876713214}]
# 5   [{'label': 'display', 'lat': 41.879321000000004, 'lng': -87.625508}]
# 6   [{'label': 'display', 'lat': 41.874670691907355, 'lng': -87.62552529638134}]
# 7   [{'label': 'display', 'lat': 41.8741292184772, 'lng': -87.62606358943373}]
# 8   [{'label': 'display', 'lat': 41.875607, 'lng': -87.624503}]
# 9   [{'label': 'display', 'lat': 41.87571237049921, 'lng': -87.62500047683716}]
# 10  [{'label': 'display', 'lat': 41.87430180555001, 'lng': -87.62912378722385}]
# 11  [{'label': 'display', 'lat': 41.879632, 'lng': -87.626753}]
# 12  [{'label': 'display', 'lat': 41.87958409645068, 'lng': -87.62184606033443}]
# 13  [{'label': 'display', 'lat': 41.87937231091048, 'lng': -87.62673858744276}]
# 14  [{'label': 'display', 'lat': 41.879262, 'lng': -87.626611}]
# 15  [{'label': 'display', 'lat': 41.87980606438684, 'lng': -87.62596591869482}]
# 16  [{'label': 'display', 'lat': 41.874879, 'lng': -87.628939}]
# 17  [{'label': 'display', 'lat': 41.87664114402268, 'lng': -87.63069212152591}]
# 18  [{'label': 'display', 'lat': 41.877361, 'lng': -87.628751}]
# 19  [{'label': 'display', 'lat': 41.87778146968472, 'lng': -87.6306040365589}]
# 20  [{'label': 'display', 'lat': 41.875304850081875, 'lng': -87.62921970466826}]
# 21  [{'label': 'display', 'lat': 41.874025012001574, 'lng': -87.62898086313432}]
# 22  [{'label': 'display', 'lat': 41.8795495480299, 'lng': -87.62692898511887}]
#
#     location.distance location.postalCode location.cc location.city  \
# 0   573                60603               US          Chicago
# 1   445                60604               US          Chicago
# 2   360                60604               US          Chicago
# 3   373                60605               US          Chicago
# 4   555                60605               US          Chicago
# 5   494                60603               US          Chicago
# 6   64                 60605               US          Chicago
# 7   134                60605               US          Chicago
# 8   82                 60605               US          Chicago
# 9   90                 60611               US          Chicago
# 10  363                60605               US          Chicago
# 11  549                60603               US          Chicago
# 12  575                NaN                 US          Chicago
# 13  521                60603               US          Chicago
# 14  506                60603               US          Chicago
# 15  553                60603               US          Chicago
# 16  341                60605               US          Chicago
# 17  523                60605               US          Chicago
# 18  425                60604               US          Chicago
# 19  576                60604               US          Chicago
# 20  367                60605               US          Chicago
# 21  358                60605               US          Chicago
# 22  545                60603               US          Chicago
#
#    location.state location.country  \
# 0   IL             United States
# 1   IL             United States
# 2   IL             United States
# 3   IL             United States
# 4   IL             United States
# 5   IL             United States
# 6   IL             United States
# 7   IL             United States
# 8   IL             United States
# 9   IL             United States
# 10  IL             United States
# 11  IL             United States
# 12  IL             United States
# 13  IL             United States
# 14  IL             United States
# 15  IL             United States
# 16  IL             United States
# 17  IL             United States
# 18  IL             United States
# 19  IL             United States
# 20  IL             United States
# 21  IL             United States
# 22  IL             United States
#
#                                                                        location.formattedAddress  \
# 0   [17 W Adams St (btwn S Dearborn St & S State St), Chicago, IL 60603, United States]
# 1   [226 S Wabash Ave, Chicago, IL 60604, United States]
# 2   [327 S Plymouth Ct (btwn W Jackson Blvd & W Van Buren St), Chicago, IL 60604, United States]
# 3   [616 S Dearborn St, Chicago, IL 60605, United States]
# 4   [899 S Plymouth Ct (at W 9th St), Chicago, IL 60605, United States]
# 5   [65 E Adams St (Wabash), Chicago, IL 60603, United States]
# 6   [63 E Harrison St (Wabash), Chicago, IL 60605, United States]
# 7   [606 S Wabash Ave, Chicago, IL 60605, United States]
# 8   [520 S Michigan Ave (Congress Parkway), Chicago, IL 60605, United States]
# 9   [595 Vail Valley Drive, Chicago, IL 60611, United States]
# 10  [600 S Dearborn St, Chicago, IL 60605, United States]
# 11  [24 E Adams St, Chicago, IL 60603, United States]
# 12  [Chicago, IL, United States]
# 13  [24 E Adams St (at Wabash), Chicago, IL 60603, United States]
# 14  [29 E Adams St, Chicago, IL 60603, United States]
# 15  [134 S Wabash Ave (btwn E Adams & E Monroe St), Chicago, IL 60603, United States]
# 16  [539 S Dearborn St (at W Harrison St), Chicago, IL 60605, United States]
# 17  [406 S Clark St (Van Buren), Chicago, IL 60605, United States]
# 18  [327 S Plymouth Ct, Chicago, IL 60604, United States]
# 19  [77 W Jackson Blvd (at S Clark St), Chicago, IL 60604, United States]
# 20  [521 S Dearborn St (at Congress Pkwy), Chicago, IL 60605, United States]
# 21  [610 S Dearborn St (at W Harrison St), Chicago, IL 60605, United States]
# 22  [24 E Adams St, Chicago, IL 60603, United States]
#
#    location.neighborhood                        id
# 0   NaN                   4b2bedd4f964a520e6bd24e3
# 1   NaN                   40b28c80f964a52037fb1ee3
# 2   NaN                   4b9ad8c5f964a520ccdb35e3
# 3   NaN                   51d896fc498ea6557a53478f
# 4   NaN                   4a4d85a8f964a520f9ad1fe3
# 5   The Loop              5d8136d5adf8620008fd8200
# 6   NaN                   58a3360a3493553f56f942a7
# 7   NaN                   59866e4616ef6757600d2419
# 8   NaN                   4e99a54a30f8e35f55cc3852
# 9   NaN                   53b667f8498e13dbda6f1b45
# 10  NaN                   4b3aca57f964a5207b6e25e3
# 11  NaN                   5c114c8d2a7ab6002c9c6105
# 12  NaN                   5220fe1b498ebc08f2dc3f56
# 13  NaN                   4c22547b9085d13a742886cc
# 14  NaN                   4cf44dcf6195721eef9251c1
# 15  The Loop              49d8159cf964a520a05d1fe3
# 16  NaN                   4bfa87015efe2d7f77b46d34
# 17  NaN                   4bd9c2e3e914a59305c957fa
# 18  NaN                   4bad0cc6f964a52052283be3
# 19  NaN                   4d63f9ffd37c88bf879535c1
# 20  NaN                   4b47fdf5f964a520f24526e3
# 21  NaN                   4bb541582f70c9b6b0008430
# 22  NaN                   52efeef5498e5dceb7c8360f

# %%
# clean column names by keeping only last term
dataframe_filtered.columns = [ column.split('.')[-1] for column in dataframe_filtered.columns ]
dataframe_filtered

dataframe_filtered.name
# Out:
# 0     The Berghoff Restaurant
# 1     Exchequer Restaurant & Pub
# 2     Plymouth Restaurant & Bar
# 3     Sofi Restaurant
# 4     Chicago Curry House Indian Restaurant
# 5     Opus Restaurant & Café
# 6     Luna Cafe Restaurant
# 7     Himalayan Restaurant
# 8     Gazebo Restaurant at Grant Park
# 9     Lord Gore Restaurant
# 10    Amarit Thai Restaurant
# 11    Rawabi Grill Mediterranean Restaurant
# 12    McKinlock Court Restaurant
# 13    G & G Restaurant
# 14    HALO' Restaurant - Chicago
# 15    Miller's Pub
# 16    Dearborn Dentistry
# 17    La Cocina Mexican Grill
# 18    Plymouth Street
# 19    Subway
# 20    Gino's East
# 21    S.R.O. - Standing Room Only
# 22    Middle Eastern Restaurants
# Name: name, dtype: object

# %%
 # generate map centred around the Conrad Hotel
venues_map = folium.Map(location= [ latitude, longitude ], zoom_start=15)

# add a red circle marker to represent the Conrad Hotel
folium.vector_layers.CircleMarker(
    location= [ latitude, longitude ],
    radius = 10,
    color = 'red',
    popup = 'Conrad Hotel',
    fill  = True,
    fill_color = 'BLACK',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.vector_layers.CircleMarker(
        location= [ lat, lng ],
        radius=10,
        color='blue',
        popup=label,
        fill = True,
        fill_color='BLACK',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# CHECK VENUE RATINGS AND TIPS COUNT 

venue_id = '40b28c80f964a52037fb1ee3' # ID of Pretty Boy Italian Steakhouse
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
venue  = result['response']['venue']

try:
    print("Venue rating: {}".format(venue['rating']))
except:
    print('This venue has not been rated yet.')

tips = venue['tips']['count']
print("Tips count : {}".format(tips))
# Out:
# Venue rating: 7.6
# Tips count : 78

# %%
## Ecco Tipslimit = 15 # set limit to be greater than or equal to the total number of tips
limit = 15
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()

tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
#tip.keys()

#Get tips for locations
pd.set_option('display.max_colwidth', -1)
tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = [ 'text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id' ]
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'url', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'lastVoteText', 'lastUpvoteTimestamp', 'todo', 'user'])

# %%
# display trending venues nearby given location latitude and longitute
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
trending_venues = results['response']['venues'];

if len(trending_venues) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
else:
    trending_venues_df = json_normalize(trending_venues)
    # filter columns
    columns_filtered = [ 'name', 'categories' ] + [ 'location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng' ]
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

trending_venues_df
# Out:
# No trending venues are available at the moment!

# %%
# display map markers on found trending places around given location 

if len(trending_venues) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco
    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'
