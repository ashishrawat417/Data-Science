# %% [markdown]
# ## Assignment_2 Requirement
# Your code needs to:
# * Load the dataset (you need to use this library : from pandas import read_csv)
# * Describe the data: printing the shape of the dataset, the type of data, and related
# correlation correlation
# * Visualize the data (at least with pyplot)
# * Split the data into train and test (20% of the entire data for test). You can also
# use 10% of data for validation if you want.
# * Train, test and compare the performance of the three developed models

# %%
from pandas.plotting import scatter_matrix
from pandas import read_csv
from matplotlib import pyplot
#Reading the data
filename = 'housing.csv'

names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
dataset = read_csv(filename, delim_whitespace=True, names=names)

#Describe and Displaying the data

print(dataset.shape)
scatter_matrix(dataset)
pyplot.show()

#Train Test Split
from sklearn.model_selection import train_test_split
array = dataset.values
X = array[:,0:13]
Y = array[:,13]
validation_size = 0.20
seed = 7
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=validation_size, random_state=seed)

#KNN, SVC, and LR parameter tuning
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

model = KNeighborsRegressor(n_neighbors=2) #They are lots of parameters that you can set, what I need you to chech is n_neighbors 
model =  LinearRegression(normalize=False)#normalize=False or true
model = SVR(C=1.0, epsilon=0.2)

#Metric
from sklearn.metrics import mean_squared_error
predictions = model.predict(X_test)
print(mean_squared_error(Y_test, predictions))
# Out:
# (506, 14)
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-1-00220d85b9cd> in <module>
#      37 #Metric
#      38 from sklearn.metrics import mean_squared_error
# ---> 39 predictions = model.predict(X_test)
#      40 print(mean_squared_error(Y_test, predictions))
#
# C:\Anaconda\envs\ANN\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     313         y_pred : array, shape (n_samples,)
#     314         """
# --> 315         X = self._validate_for_predict(X)
#     316         predict = self._sparse_predict if self._sparse else self._dense_predict
#     317         return predict(X)
#
# C:\Anaconda\envs\ANN\lib\site-packages\sklearn\svm\_base.py in _validate_for_predict(self, X)
#     442
#     443     def _validate_for_predict(self, X):
# --> 444         check_is_fitted(self)
#     445
# ...

# %% [markdown]
# ## Tunning parameters for SVC
#
# kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}, default=’rbf’
# Specifies the kernel type to be used in the algorithm. It must be one of ‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’ or a callable. If none is given, ‘rbf’ will be used. If a callable is given it is used to precompute the kernel matrix.
#
# epsilonfloat, default=0.1
# Epsilon in the epsilon-SVR model. It specifies the epsilon-tube within which no penalty is associated in the training loss function with points predicted within a distance epsilon from the actual value

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html
